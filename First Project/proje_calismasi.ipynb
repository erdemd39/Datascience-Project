# %% [markdown]
# # İntroduction
# <span style = "color:blue">
# ilk fazda NYC Eyalatine ait AirBNB datasını inceleyip mahallelere göre fiyat, oda türü ve konaklama uygunluğuna göre verileri analiz edip, ikinci fazda 2020 yılına ait etkinlik verisi ile AirBnb verisini karşılaştırıp uygun konaklama altarnatifini analizetmeyi hedeflemekteyim.
#
# </span>
# Content:
#
#
# 1. Load and Check Data
# 2. Variable Description
#
#    2.1.Univariate Variable Analysis
#    2.1.1 Categorical Variable
#    2.1.2 Numerical Variable

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Load and Check Data

# %%
df = pd.read_csv(
    'C:/Users/ERDEM/NYC AirBNB data/AB_NYC_2019.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
# id                                48895 non-null int64
# name                              48879 non-null object
# host_id                           48895 non-null int64
# host_name                         48874 non-null object
# neighbourhood_group               48895 non-null object
# neighbourhood                     48895 non-null object
# latitude                          48895 non-null float64
# longitude                         48895 non-null float64
# room_type                         48895 non-null object
# price                             48895 non-null int64
# minimum_nights                    48895 non-null int64
# number_of_reviews                 48895 non-null int64
# last_review                       38843 non-null object
# reviews_per_month                 38843 non-null float64
# calculated_host_listings_count    48895 non-null int64
# ...

# %% [markdown]
# *float64(1): calculated_host_listings_count
#
#    *int64(7)  : id,host_id,price,minimum_nights,number_of_reviews,calculated_host_listings_count,availability_365
#
#    *object(5) : name,host_name,neighbourhood_group,room_type,last_review

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %% [markdown]
# # Univariate Variable Analysis
#
# * Categorical Variable: name,host_name,neighbourhood_group,room_type
#
# * Numerical Variable: host_id,id,price,minimum_nights,number_of_reviews,calculated_host_listings_count, availability_365

# %%
df.room_type.value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
df.host_name.value_counts()
# Out:
# Michael         417
# David           403
# Sonder (NYC)    327
# John            294
# Alex            279
#                ...
# Sehrish           1
# Raizy             1
# Seza              1
# Cordelia          1
# Omowumi           1
# Name: host_name, Length: 11452, dtype: int64

# %%
df.groupby(['neighbourhood_group'])[['room_type','price']].max()
# Out:
#                        room_type  price
# neighbourhood_group
# Bronx                Shared room   2500
# Brooklyn             Shared room  10000
# Manhattan            Shared room  10000
# Queens               Shared room  10000
# Staten Island        Shared room   5000

# %%
df.iloc[0:200,8:10]
# Out:
#            room_type  price
# 0       Private room    149
# 1    Entire home/apt    225
# 2       Private room    150
# 3    Entire home/apt     89
# 4    Entire home/apt     80
# ..               ...    ...
# 195     Private room    123
# 196     Private room     55
# 197  Entire home/apt    195
# 198     Private room     80
# 199  Entire home/apt     98
#
# [200 rows x 2 columns]

# %%
df.iloc[0:200,8:10].groupby(['room_type','price']).sum()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
(df
 .groupby(['neighbourhood_group','room_type'])
 .mean()
 .reset_index()
 .sort_values(['minimum_nights','price'], ascending=[True,False])
)
# Out:
#    neighbourhood_group        room_type            id       host_id  \
# 14       Staten Island      Shared room  3.061484e+07  7.713866e+07
# 2                Bronx      Shared room  2.705442e+07  1.123450e+08
# 13       Staten Island     Private room  2.106201e+07  1.017539e+08
# 1                Bronx     Private room  2.235896e+07  1.060786e+08
# 11              Queens      Shared room  2.469434e+07  1.123200e+08
# 10              Queens     Private room  2.197231e+07  1.008169e+08
# 9               Queens  Entire home/apt  2.112772e+07  8.713280e+07
# 7            Manhattan     Private room  1.880759e+07  6.982314e+07
# 4             Brooklyn     Private room  1.894125e+07  6.242636e+07
# 0                Bronx  Entire home/apt  2.269787e+07  1.037373e+08
# 12       Staten Island  Entire home/apt  2.170833e+07  9.618779e+07
# 3             Brooklyn  Entire home/apt  1.730117e+07  4.861704e+07
# 8            Manhattan      Shared room  2.115615e+07  9.666720e+07
# ...

# %%
def bar_plot(variable):
    """
        input: variable ex: "room_type"
        output: bar plot & value count
    """
    # get feature
    var = df[variable]
    # count number of categorical variable(value/sample)
    varValue = var.value_counts()
    
    # visualize
    plt.figure(figsize = (9,3))
    plt.bar(varValue.index, varValue)
    plt.xticks(varValue.index, varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
category1 = ["neighbourhood_group","room_type"]
for i in category1:
    bar_plot(i)
# Out:
# neighbourhood_group:
#  Manhattan        21661
# Brooklyn         20104
# Queens            5666
# Bronx             1091
# Staten Island      373
# Name: neighbourhood_group, dtype: int64
# room_type:
#  Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %% [markdown]
# # Numerical Variable

# %%
def plot_hist(variable):
    plt.figure(figsize = (5,3))
    plt.hist(df[variable])
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} distribution with hist".format(variable))

    plt.show()

# %%
numericVar = ["availability_365", "number_of_reviews"]
for n in numericVar:
    plot_hist(n)

# %% [markdown]
# # Basic Data Analysis

# %%
# Plcass vs Survived
df[["price","minimum_nights"]].groupby(["minimum_nights"], as_index = False).mean().sort_values(by="price",ascending = False)
# Out:
#      minimum_nights        price
# 64               99  5039.000000
# 68              114  4200.000000
# 65              100   936.533333
# 37               40   437.538462
# 107            1000   400.000000
# ..              ...          ...
# 103             400    50.000000
# 47               58    40.000000
# 57               85    35.000000
# 35               37    33.000000
# 73              134    29.000000
#
# [109 rows x 2 columns]

# %%
df[["neighbourhood_group","price"]].groupby(["neighbourhood_group"], as_index = False).mean().sort_values(by="price",ascending = False)
# Out:
#   neighbourhood_group       price
# 2           Manhattan  196.875814
# 1            Brooklyn  124.383207
# 4       Staten Island  114.812332
# 3              Queens   99.517649
# 0               Bronx   87.496792

# %%
df[["neighbourhood_group","minimum_nights",'price']].groupby(["neighbourhood_group"],
 as_index = False).min().sort_values(by="price",ascending = False)
# Out:
#   neighbourhood_group  minimum_nights  price
# 4       Staten Island               1     13
# 3              Queens               1     10
# 0               Bronx               1      0
# 1            Brooklyn               1      0
# 2           Manhattan               1      0

# %%
df[["neighbourhood_group","minimum_nights",'price']].groupby(["neighbourhood_group"],
 as_index = False).max().sort_values(by="minimum_nights",ascending = False)
# Out:
#   neighbourhood_group  minimum_nights  price
# 2           Manhattan            1250  10000
# 1            Brooklyn             999  10000
# 3              Queens             500  10000
# 0               Bronx             365   2500
# 4       Staten Island             365   5000

# %%
df.groupby(['neighbourhood_group','room_type'])[['room_type','price']].count()
# Out:
#                                      room_type  price
# neighbourhood_group room_type
# Bronx               Entire home/apt        379    379
#                     Private room           652    652
#                     Shared room             60     60
# Brooklyn            Entire home/apt       9559   9559
#                     Private room         10132  10132
#                     Shared room            413    413
# Manhattan           Entire home/apt      13199  13199
#                     Private room          7982   7982
#                     Shared room            480    480
# Queens              Entire home/apt       2096   2096
#                     Private room          3372   3372
#                     Shared room            198    198
# Staten Island       Entire home/apt        176    176
#                     Private room           188    188
#                     Shared room              9      9

# %%
feq=df.groupby(['neighbourhood_group'])[['room_type']].count()
feq.plot.bar(figsize=(10, 8), color='b', width=1, rot=0)
plt.title("Accommodates (number of people)", fontsize=20)
plt.ylabel('room_type', fontsize=12)
plt.xlabel('neighbourhood_group', fontsize=12)
plt.show()

# %% [markdown]
# # Missing Value

# %% [markdown]
# # *Find Missing Value *Fill Missing Value

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['name', 'host_name', 'last_review', 'reviews_per_month'], dtype='object')

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df[df["name"].isnull()]
# Out:
#              id name   host_id host_name neighbourhood_group  \
# 2854    1615764  NaN   6676776     Peter           Manhattan
# 3703    2232600  NaN  11395220      Anna           Manhattan
# 5775    4209595  NaN  20700823     Jesse           Manhattan
# 5975    4370230  NaN  22686810   Michaël           Manhattan
# 6269    4581788  NaN  21600904     Lucie            Brooklyn
# 6567    4756856  NaN   1832442  Carolina            Brooklyn
# 6605    4774658  NaN  24625694      Josh           Manhattan
# 8841    6782407  NaN  31147528  Huei-Yin            Brooklyn
# 11963   9325951  NaN  33377685  Jonathan           Manhattan
# 12824   9787590  NaN  50448556    Miguel           Manhattan
# 13059   9885866  NaN  37306329  Juliette           Manhattan
# 13401  10052289  NaN  49522403   Vanessa            Brooklyn
# 15819  12797684  NaN  69715276       Yan           Manhattan
# 16071  12988898  NaN  71552588    Andrea               Bronx
# ...

# %%
df["name"] = df["name"].fillna("Noname")
df[df["name"].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
g = sns.factorplot(x = "neighbourhood_group", y = "price", data = df, kind = "bar", size = 6)
g.set_ylabels("price")
plt.show()
# Out:
# C:\Users\ERDEM\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\ERDEM\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.FacetGrid(df, col = "neighbourhood_group")
g.map(sns.distplot, "price", bins = 25)
plt.show()

# %%
sns.factorplot(x = "room_type", y = "minimum_nights", data = df, kind = "box")
plt.show()

# %%
sns.factorplot(x = "neighbourhood_group", y = "price", hue = "room_type",data = df, kind = "box")
plt.show()
# Out:
# C:\Users\ERDEM\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
